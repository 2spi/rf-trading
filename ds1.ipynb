# %%
import pandas as pd

# %%
df = pd.read_csv('1hour.csv')

# %%
df.head()
# Out:
#    1502942400.0  4261.48000000  4313.62000000  4261.32000000  4308.83000000  \
# 0  1.502946e+09        4308.83        4328.69        4291.37        4315.32
# 1  1.502950e+09        4330.29        4345.45        4309.37        4324.35
# 2  1.502953e+09        4316.62        4349.99        4287.41        4349.99
# 3  1.502957e+09        4333.32        4377.85        4333.32        4360.69
# 4  1.502960e+09        4360.00        4445.78        4360.00        4444.00
#
#    47.18100900  1502945999999
# 0    23.234916  1502949599999
# 1     7.229691  1502953199999
# 2     4.443249  1502956799999
# 3     0.972807  1502960399999
# 4    10.763623  1502963999999

# %%
column_names = ['Open time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close time']

# %%
df.columns = column_names

# %%
df.head()
# Out:
#       Open time     Open     High      Low    Close     Volume     Close time
# 0  1.502946e+09  4308.83  4328.69  4291.37  4315.32  23.234916  1502949599999
# 1  1.502950e+09  4330.29  4345.45  4309.37  4324.35   7.229691  1502953199999
# 2  1.502953e+09  4316.62  4349.99  4287.41  4349.99   4.443249  1502956799999
# 3  1.502957e+09  4333.32  4377.85  4333.32  4360.69   0.972807  1502960399999
# 4  1.502960e+09  4360.00  4445.78  4360.00  4444.00  10.763623  1502963999999

# %%
pd.to_datetime(1502942400.0, unit='s')
# Out:
# Timestamp('2017-08-17 04:00:00')

# %%
pd.to_datetime(df['Open time'], unit='s')
# Out:
# 0       2017-08-17 05:00:00
# 1       2017-08-17 06:00:00
# 2       2017-08-17 07:00:00
# 3       2017-08-17 08:00:00
# 4       2017-08-17 09:00:00
#                 ...
# 53880   2023-10-15 13:00:00
# 53881   2023-10-15 14:00:00
# 53882   2023-10-15 15:00:00
# 53883   2023-10-15 16:00:00
# 53884   2023-10-15 17:00:00
# Name: Open time, Length: 53885, dtype: datetime64[ns]

# %%
df['Open time'] = pd.to_datetime(df['Open time'], unit='s')

# %%
df.head()
# Out:
#             Open time     Open     High      Low    Close     Volume  \
# 0 2017-08-17 05:00:00  4308.83  4328.69  4291.37  4315.32  23.234916
# 1 2017-08-17 06:00:00  4330.29  4345.45  4309.37  4324.35   7.229691
# 2 2017-08-17 07:00:00  4316.62  4349.99  4287.41  4349.99   4.443249
# 3 2017-08-17 08:00:00  4333.32  4377.85  4333.32  4360.69   0.972807
# 4 2017-08-17 09:00:00  4360.00  4445.78  4360.00  4444.00  10.763623
#
#       Close time
# 0  1502949599999
# 1  1502953199999
# 2  1502956799999
# 3  1502960399999
# 4  1502963999999

# %%
df['Close time'] = pd.to_datetime(df['Close time'], unit='ms')

# %%
df.head()
# Out:
#             Open time     Open     High      Low    Close     Volume  \
# 0 2017-08-17 05:00:00  4308.83  4328.69  4291.37  4315.32  23.234916
# 1 2017-08-17 06:00:00  4330.29  4345.45  4309.37  4324.35   7.229691
# 2 2017-08-17 07:00:00  4316.62  4349.99  4287.41  4349.99   4.443249
# 3 2017-08-17 08:00:00  4333.32  4377.85  4333.32  4360.69   0.972807
# 4 2017-08-17 09:00:00  4360.00  4445.78  4360.00  4444.00  10.763623
#
#                Close time
# 0 2017-08-17 05:59:59.999
# 1 2017-08-17 06:59:59.999
# 2 2017-08-17 07:59:59.999
# 3 2017-08-17 08:59:59.999
# 4 2017-08-17 09:59:59.999

# %%
df.isna().sum()
# Out:
# Open time     0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Close time    0
# dtype: int64

# %% [markdown]
# ### Training, Validation, and Test Data (Jan 1, 2018, to Jan 31, 2022)

# %%
start_date = pd.to_datetime('2018-01-01 00:00:00')
end_date = pd.to_datetime('2022-01-31 23:00:00')
main = df[(df["Open time"] >= start_date) & (df["Open time"] <= end_date)]

# %%
main
# Out:
#                 Open time      Open      High       Low     Close  \
# 3277  2018-01-01 00:00:00  13715.65  13715.65  13400.01  13529.01
# 3278  2018-01-01 01:00:00  13528.99  13595.89  13155.38  13203.06
# 3279  2018-01-01 02:00:00  13203.00  13418.43  13200.00  13330.18
# 3280  2018-01-01 03:00:00  13330.26  13611.27  13290.00  13410.03
# 3281  2018-01-01 04:00:00  13434.98  13623.29  13322.15  13601.01
# ...                   ...       ...       ...       ...       ...
# 38959 2022-01-31 19:00:00  38468.29  38744.00  38383.91  38415.79
# 38960 2022-01-31 20:00:00  38415.79  38563.37  38236.69  38450.62
# 38961 2022-01-31 21:00:00  38450.62  38531.53  38335.00  38410.09
# 38962 2022-01-31 22:00:00  38410.09  38737.99  38398.58  38412.46
# 38963 2022-01-31 23:00:00  38412.45  38510.28  38336.04  38466.90
#
#             Volume              Close time
# 3277    443.356199 2018-01-01 00:59:59.999
# 3278    383.697006 2018-01-01 01:59:59.999
# ...

# %% [markdown]
# ### Out-of-Sample 1 (Feb 1, 2022, to Dec 31, 2022)

# %%
start_date_1 = pd.to_datetime('2022-02-01 00:00:00')
end_date_1 = pd.to_datetime('2022-12-31 23:00:00')
oos_1 = df[(df["Open time"] >= start_date_1) & (df["Open time"] <= end_date_1)]

# %%
oos_1
# Out:
#                 Open time      Open      High       Low     Close      Volume  \
# 38964 2022-02-01 00:00:00  38466.90  38627.35  38276.43  38342.36  1058.42599
# 38965 2022-02-01 01:00:00  38342.37  38407.00  38175.86  38238.19   777.86310
# 38966 2022-02-01 02:00:00  38238.18  38506.18  38196.61  38480.90   766.83847
# 38967 2022-02-01 03:00:00  38480.90  38649.90  38384.99  38596.82   946.45649
